# %% [markdown]
# DIPK, no randomization, LCO.

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt

dataset = []
for i in range(5):
    current_dataset = pd.read_csv(f"./Data/DIPK/no_randomization/predictions_split_{i}.csv")
    dataset.append(current_dataset)

dataset = pd.concat(dataset, ignore_index=True)
MSE = (sum((dataset.loc[:,"predictions"] - dataset.loc[:,"response"])**2))/len(dataset)
pearson = pearsonr(dataset.loc[:,"predictions"], dataset.loc[:,"response"]).statistic

MSE = round(MSE, 3)
pearson = round(pearson, 3)

plt.text(-7, 9, f"DIPK No Randomization \nMSE: {MSE} \nPearson: {pearson}", fontsize = 10, c='r')
plt.xlabel("Predicted Values")
plt.ylabel("Ground Truth Values")
plt.scatter(dataset.loc[:,"predictions"], dataset.loc[:,"response"], s=2)
plt.show()

# %% [markdown]
# DIPK, randomized gene expression features, LCO.

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt

dataset = []
for i in range(5):
    current_dataset = pd.read_csv(f"./Data/DIPK/randomizing_CCLs/randomization_SVCC_biological_network_features_split_{i}.csv")
    dataset.append(current_dataset)

dataset = pd.concat(dataset, ignore_index=True)
MSE = (sum((dataset.loc[:,"predictions"] - dataset.loc[:,"response"])**2))/len(dataset)
pearson = pearsonr(dataset.loc[:,"predictions"], dataset.loc[:,"response"]).statistic

MSE = round(MSE, 3)
pearson = round(pearson, 3)

plt.text(-5, 8.8, f"DIPK Randomized Gene Expression Features \nMSE: {MSE} \nPearson: {pearson}", fontsize = 10, c='r')
plt.xlabel("Predicted Values")
plt.ylabel("Ground Truth Values")
plt.scatter(dataset.loc[:,"predictions"], dataset.loc[:,"response"], s=2)
plt.show()

# %% [markdown]
# DIPK, randomized biological network features, LCO.

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt

dataset = []
for i in range(5):
    current_dataset = pd.read_csv(f"./Data/DIPK/randomizing_CCLs/randomization_SVCC_gene_expression_features_split_{i}.csv")
    dataset.append(current_dataset)

dataset = pd.concat(dataset, ignore_index=True)
MSE = (sum((dataset.loc[:,"predictions"] - dataset.loc[:,"response"])**2))/len(dataset)
pearson = pearsonr(dataset.loc[:,"predictions"], dataset.loc[:,"response"]).statistic

MSE = round(MSE, 3)
pearson = round(pearson, 3)

plt.text(-6.8, 9, f"DIPK Randomized Biological Network Features \nMSE: {MSE} \nPearson: {pearson}", fontsize = 10, c='r')
plt.xlabel("Predicted Values")
plt.ylabel("Ground Truth Values")
plt.scatter(dataset.loc[:,"predictions"], dataset.loc[:,"response"], s=2)
plt.show()

# %% [markdown]
# DIPK, randomized MolGNet features, LCO.

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt

dataset = []
for i in range(5):
    current_dataset = pd.read_csv(f"./Data/DIPK/randomizing_Drugs/MolGNet/predictions_split_{i}.csv")
    dataset.append(current_dataset)

dataset = pd.concat(dataset, ignore_index=True)
MSE = (sum((dataset.loc[:,"predictions"] - dataset.loc[:,"response"])**2))/len(dataset)
pearson = pearsonr(dataset.loc[:,"predictions"], dataset.loc[:,"response"]).statistic

MSE = round(MSE, 3)
pearson = round(pearson, 3)

plt.text(-6.5, 8.8, f"DIPK Randomized MolGNet Features \nMSE: {MSE} \nPearson: {pearson}", fontsize = 10, c='r')
plt.xlabel("Predicted Values")
plt.ylabel("Ground Truth Values")
plt.scatter(dataset.loc[:,"predictions"], dataset.loc[:,"response"], s=2)
plt.show()

# %% [markdown]
# DIPK, randomized edge indices, LCO.

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt

dataset = []
for i in range(5):
    current_dataset = pd.read_csv(f"./Data/DIPK/randomizing_Drugs/Edges/predictions_split_{i}.csv")
    dataset.append(current_dataset)

dataset = pd.concat(dataset, ignore_index=True)
MSE = (sum((dataset.loc[:,"predictions"] - dataset.loc[:,"response"])**2))/len(dataset)
pearson = pearsonr(dataset.loc[:,"predictions"], dataset.loc[:,"response"]).statistic

MSE = round(MSE, 3)
pearson = round(pearson, 3)

plt.text(-6.5, 9, f"DIPK Randomized Edge Indices \nMSE: {MSE} \nPearson: {pearson}", fontsize = 10, c='r')
plt.xlabel("Predicted Values")
plt.ylabel("Ground Truth Values")
plt.scatter(dataset.loc[:,"predictions"], dataset.loc[:,"response"], s=2)
plt.show()
